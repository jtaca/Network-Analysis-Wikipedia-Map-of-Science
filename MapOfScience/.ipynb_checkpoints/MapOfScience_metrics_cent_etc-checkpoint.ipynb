# %%
document = open('MapOfScience.gml', 'r').read()
document = document.split('Version 1.0')[1]
document = document.split('node\n')[1:]
nodes = document[:687]
nodes.append(document[686:][0].split('edge')[0])
final_nodes=[]
for node in nodes:
    node_id = int(node.split('id')[1][:5].split(' ')[1])
    node_name = node.split('name "')[1].split('"')[0]
    node_class = node.split('Class "')[1].split('"')[0]
    node_url = node.split('WikipediaUrl "')[1].split('"')[0]
    final_nodes.append((node_id, {'name':node_name,'class': node_class,'url': node_url }))

#print(final_nodes)
import networkx as nx
G = nx.Graph()
G.add_nodes_from(final_nodes)
    
edges = document[686:][0].split('edge')[1:]
final_egde = [] 
print(len(edges))

for edge in edges:
    source = int(edge.split('source')[1][:5].split(' ')[1])
    target = int(edge.split('target')[1][:5].split(' ')[1])
    CosineSimilarity = float(edge.split('CosineSimilarity')[1][:18].split(' ')[1])
    G.add_edge(source, target, weight = CosineSimilarity)
    
    
    
print(final_nodes[0])
print(nx.info(G))
# Out:
# 13046
# (0, {'name': 'Accounting', 'class': 'Applied', 'url': 'https://en.wikipedia.org/wiki/Accounting'})
# Name:
# Type: Graph
# Number of nodes: 687
# Number of edges: 6523
# Average degree:  18.9898

# %%
#Centrality

#print(sorted(nx.degree_centrality(G).values(), reverse=True))
#sorted_degree_centrality = sorted(nx.degree_centrality(G).items(), reverse=True, key=lambda item: item[1])
#{print(f'{k:<4} : {v}') for k, v in sorted_degree_centrality}

#G.nodes[sorted_degree_centrality[0][0]]
    

#sorted_degree_centrality_in = sorted(nx.in_degree_centrality(G).items(), reverse=True, key=lambda item: item[1])

#for i in range(len(sorted_degree_centrality)):
#    print(f'{sorted_degree_centrality[i][1]}, {sorted_degree_centrality_in[i][1]}')


#print(nx.in_degree_centrality(G))
#print(nx.out_degree_centrality(G))


#print(nx.closeness_centrality(G))
#print(nx.betweenness_centrality(G))
#print(nx.betweenness_centrality_source(G))
#print(nx.edge_betweenness_centrality(G))
#print(nx.voterank(G))
# Out:
# {0: 0.01020408163265306, 1: 0.014577259475218658, 2: 0.013119533527696793, 3: 0.0029154518950437317, 4: 0.007288629737609329, 5: 0.0029154518950437317, 6: 0.0058309037900874635, 7: 0.007288629737609329, 8: 0.023323615160349854, 9: 0.04518950437317784, 10: 0.01749271137026239, 11: 0.011661807580174927, 12: 0.004373177842565598, 13: 0.004373177842565598, 14: 0.004373177842565598, 15: 0.037900874635568516, 16: 0.01020408163265306, 17: 0.026239067055393587, 18: 0.0058309037900874635, 19: 0.06268221574344023, 20: 0.004373177842565598, 21: 0.0058309037900874635, 22: 0.007288629737609329, 23: 0.0058309037900874635, 24: 0.023323615160349854, 25: 0.08746355685131195, 26: 0.011661807580174927, 27: 0.021865889212827987, 28: 0.007288629737609329, 29: 0.004373177842565598, 30: 0.016034985422740525, 31: 0.033527696793002916, 32: 0.02478134110787172, 33: 0.004373177842565598, 34: 0.0058309037900874635, 35: 0.04664723032069971, 36: 0.011661807580174927, 37: 0.03498542274052478, 38: 0.008746355685131196, 39: 0
#Approximations and Heuristics

#print(nx.all_pairs_node_connectivity(G)) # this takes a while

# %%
#Distance measures

# the graph is not stongly connected so these measures fail
#print(nx.barycenter(G))
#print(nx.center(G))
#print(nx.diameter(G))
#print(nx.eccentricity(G))
#print(nx.periphery(G))


# Eulerian - path in a finite graph that visits every edge exactly once.
print(nx.is_eulerian(G))
# Out:
# False

# %%
#Link analysis
#print(nx.pagerank_numpy(G))
#print(nx.hits_numpy(G))

# %%
#Matching
#print(nx.get_node_attributes(G, 104))
nodeDict = dict(G.nodes(data=True))
print(nodeDict[104])
print(nodeDict[109])
#print(G.edges.data("weight"))
print(nx.enumerate_all_cliques(G))
#print(nx.maximal_matching(G))
#print(nx.max_weight_matching(G)) #this probably is better for our case because we have the weights
# Out:
# {'name': 'Associative algebra', 'class': 'Formal', 'url': 'https://en.wikipedia.org/wiki/Associative_algebra'}
# {'name': 'Block design', 'class': 'Formal', 'url': 'https://en.wikipedia.org/wiki/Block_design'}
# <generator object enumerate_all_cliques at 0x7feeee0896d0>

# %%
#Reciprocity -> The reciprocity of a directed graph is defined as the ratio of the number of edges pointing 
#               in both directions to the total number of edges in the graph
print(nx.reciprocity(G))
#being this 0 it means what here?
# Out:
# 0.0

# %%
print(nx.number_of_isolates(G)) #All pages are at least referenced to or reference another science page! yay!
# Out:
# 0

# %%
#Clustering
#print(nx.transitivity(G))
#print(nx.clustering(G))
#print(nx.average_clustering(G))
#print(nx.square_clustering(G)) #Compute the squares clustering coefficient for nodes.

# %%
#print(nx.constraint(G))

# %% [markdown]
# The constraint is a measure of the extent to which a node v is invested in those nodes that are themselves invested in the neighbors of v.

# %%
#print(nx.effective_size(G)) #how important is a node given the adjacent nodes connectivity?

# %% [markdown]
# The effective size of a node’s ego network is based on the concept of redundancy. A person’s ego network has redundancy to the extent that her contacts are connected to each other as well. The nonredundant part of a person’s relationships it’s the effective size of her ego network 1.

# %%
print(nx.triangles(G)) #
# Out:
# {0: 11, 1: 29, 2: 9, 3: 1, 4: 1, 5: 1, 6: 3, 7: 9, 8: 57, 9: 155, 10: 15, 11: 8, 12: 2, 13: 2, 14: 3, 15: 119, 16: 20, 17: 24, 18: 1, 19: 273, 20: 3, 21: 5, 22: 9, 23: 2, 24: 53, 25: 853, 26: 23, 27: 39, 28: 3, 29: 0, 30: 38, 31: 122, 32: 38, 33: 3, 34: 5, 35: 210, 36: 17, 37: 122, 38: 13, 39: 1, 40: 10, 41: 2, 42: 0, 43: 3, 44: 443, 45: 0, 46: 6, 47: 0, 48: 1, 49: 23, 50: 45, 51: 601, 52: 76, 53: 1, 54: 0, 55: 80, 56: 45, 57: 1, 58: 1, 59: 0, 60: 43, 61: 3, 62: 5, 63: 63, 64: 1, 65: 1, 66: 225, 67: 0, 68: 1, 69: 34, 70: 63, 71: 16, 72: 139, 73: 43, 74: 32, 75: 10, 76: 3, 77: 122, 78: 3, 79: 63, 80: 0, 81: 0, 82: 35, 83: 53, 84: 4, 85: 9, 86: 2, 87: 1, 88: 619
: 38, 342: 0, 343: 0, 344: 48, 345: 107, 346: 1, 347: 8, 348: 195, 349: 0, 350: 5, 351: 5, 352: 3, 353: 88, 354: 208, 355: 5, 356: 35, 357: 17, 358: 11, 359: 4, 360: 113, 361: 0, 362: 14, 363: 19, 364: 208, 365: 0, 366: 21, 367: 3, 368: 46, 369: 20, 370: 0, 371: 193, 372: 0, 373: 0, 374: 1, 375: 1, 376: 1, 377: 0, 378: 6, 379: 80, 380: 4, 381: 1, 382: 63, 383: 35, 384: 82, 385: 6, 386: 39, 387: 84, 388: 0, 389: 17, 390: 2, 391: 6, 392: 0, 393: 5, 394: 0, 395: 99, 396: 121, 397: 6, 398: 34, 399: 11, 400: 119, 401: 0, 402: 63, 403: 4, 404: 6, 405: 26, 406: 0, 407: 7, 408: 0, 409: 7, 410: 43, 411: 166, 412: 18, 413: 3, 414: 81, 415: 4, 416: 341, 417: 7, 418: 162, 419: 0, 420: 0, 421: 4, 422: 0, 423: 13, 424: 125, 425: 60, 426: 330, 427: 9, 428: 8, 429: 0, 430: 3, 431: 704, 432: 37, 433: 103, 434: 168, 435: 0, 436: 227, 437: 0, 438: 2, 439: 19, 440: 3, 441: 279, 442: 51, 443: 175, 444: 6, 445: 5, 446: 20, 447: 35, 448: 135, 449: 257, 450: 8, 451: 8, 452: 3, 453: 0, 454: 205, 4 ...

# %% [markdown]
# The triadic census is a count of how many of the 16 possible types of triads are present in a directed graph.

# %%
#The ones taking long

#print(nx.average_shortest_path_length(G)) 
#does not work becaus the graph is not weakly connected

#print(nx.diameter(G))
#print(nx.radius(G))
#does not work becaus the graph is not strongly connected


#XD WTF!? can anyone get a sense in this?

# %%
nx.draw_kamada_kawai(G) #amazing....

# %%
import pickle
#also lets maybe save this 
with open("MapOfScience_graph", "wb") as f:
        pickle.dump(G, f)

# %%
#and then open
#import pickle
import pathlib
PATH = pathlib.Path().absolute()

def main():
    with open(str(PATH) + "\\MapOfScience_graph", "rb") as f:
        G = pickle.load(f)

# %%
#print(G.size()) #naa thats weak lets get the info instead
print(nx.info(G))
print(nx.density(G))
print(nx.is_weighted(G)) #this is a weighted graph
print(nx.is_directed(G)) #this is a directed graph
#nx.degree_histogram(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 687
# Number of edges: 6523
# Average degree:  18.9898
# 0.027681939900102273
# True
# False

# %%
#Lets graph this #powerlaw
import numpy as np
import random
from matplotlib import pyplot as plt

data = nx.degree_histogram(G)

# fixed bin size
bins = np.arange(-100, 100, 1) # fixed bin size

plt.xlim([min(data)-5, max(data)+5])

plt.hist(data, bins=bins, alpha=0.5)
plt.title('Degree histogram')
plt.xlabel('node degree')
plt.ylabel('nr of nodes')

plt.show()

# %%
import sys

# !conda install --yes --prefix {sys.prefix} -c conda-forge powerlaw
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/joaotiago/opt/anaconda3/envs/PRI
#
#   added / updated specs:
#     - powerlaw
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     kiwisolver-1.2.0           |   py37hb449ec0_1          57 KB  conda-forge
#     matplotlib-base-3.3.2      |   py37h14374fa_1         6.7 MB  conda-forge
#     olefile-0.46               |     pyh9f0ad1d_1          32 KB  conda-forge
#     openssl-1.1.1h             |       haf1e3a3_0         1.9 MB  conda-forge
#     pillow-8.0.0               |   py37hf860fee_0         650 KB  conda-forge
#     powerlaw-1.4.6             |     pyh9f0ad1d_1          29 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         9.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   cycler             conda-forge/noarch::cycler-0.10.0-py_2
#   freetype           conda-forge/osx-64::freetype-2.10.3-ha233b18_0
#   jpeg               conda-forge/osx-64::jpeg-9d-h0b31af3_0
#   kiwisolver         conda-forge/osx-64::kiwisolver-1.2.0-py37hb449ec0_1
#   lcms2              conda-forge/osx-64::lcms2-2.11-h174193d_0
#   libpng             conda-forge/osx-64::libpng-1.6.37-hb0a8c7a_2
#   libtiff            conda-forge/osx-64::libtiff-4.1.0-h2ae36a8_6
#   libwebp-base       conda-forge/osx-64::libwebp-base-1.1.0-h0b31af3_3
#   lz4-c              conda-forge/osx-64::lz4-c-1.9.2-hb1e8313_3
#   matplotlib-base    conda-forge/osx-64::matplotlib-base-3.3.2-py37h14374fa_1
#   mpmath             conda-forge/noarch::mpmath-1.1.0-py_0
#   olefile            conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   pillow             conda-forge/osx-64::pillow-8.0.0-py37hf860fee_0
#   powerlaw           conda-forge/noarch::powerlaw-1.4.6-pyh9f0ad1d_1
#   zstd               conda-forge/osx-64::zstd-1.4.5-h289c70a_2
#
# The following packages will be UPDATED:
#
#   certifi                anaconda::certifi-2020.6.20-py37_0 --> conda-forge::certifi-2020.6.20-py37h2987424_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates     anaconda::ca-certificates-2020.7.22-0 --> conda-forge::ca-certificates-2020.6.20-hecda079_0
#   openssl                                          anaconda --> conda-forge
#
#
#
# Downloading and Extracting Packages
# pillow-8.0.0         | 650 KB    | ##################################### | 100%
# kiwisolver-1.2.0     | 57 KB     | ##################################### | 100%
# matplotlib-base-3.3. | 6.7 MB    | ##################################### | 100%
# openssl-1.1.1h       | 1.9 MB    | ##################################### | 100%
# powerlaw-1.4.6       | 29 KB     | ##################################### | 100%
# olefile-0.46         | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import powerlaw
import matplotlib.pyplot as plt

# %%
fit = powerlaw.Fit(data)
fit.power_law.alpha
fit.power_law.sigma
fit.distribution_compare('power_law', 'exponential')
# Out:
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Calculating best minimal value for power law fit
# /Users/joaotiago/opt/anaconda3/envs/PRI/lib/python3.7/site-packages/powerlaw.py:700: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# (0.637089134531784, 0.6403904406459175)

# %%
data = []
for i in list(G.degree()):
    data.append(i[1])# data can be list or numpy array
####
#figPDF = powerlaw.plot_pdf(data, color='b')
#powerlaw.plot_pdf(data, linear_bins=True, color='r', ax=figPDF)
#plt.show()
####

# %%
#fit.distribution_compare('power_law', 'aver')
#fig4 = fit.plot_ccdf(linewidth = 3)
#fit.power_law.plot_ccdf(ax = fig4, color = 'r', linestyle = '-')
#fit.lognormal.plot_ccdf(ax = fig4, color = 'g', linestyle = '-')
#plt.show()

# %%
print((len(nx.dominating_set(G))*100)/(G.size()))
# Out:
# 2.943430936685574

# %%
print(nx.shortest_path_length(G))
# Out:
# <generator object all_pairs_shortest_path_length at 0x7feef1241d50>

# %%
nx.is_connected(G)
# Out:
# False

# %%
print('Forever alones:')
sorted(nx.connected_components(G), key = len, reverse=True)[1:]
# Out:
# Forever alones
# [{327, 484, 569}, {377, 401, 615}, {42, 67}, {500, 598}]

# %%
nodeDict = dict(G.nodes(data=True))
print(nodeDict[327])
print(nodeDict[484])
print(nodeDict[569]['name']+'\n')

print(nodeDict[377]['name'])
print(nodeDict[401])
print(nodeDict[615])

print(nodeDict[42]['name'])
print(nodeDict[67]['name']+'\n')

print(nodeDict[500]['name'])
print(nodeDict[598]['name'])
# Out:
# {'name': 'Coastal geography', 'class': 'Natural', 'url': 'https://en.wikipedia.org/wiki/Coastal_geography'}
# {'name': 'Coastal geography', 'class': 'Social', 'url': 'https://en.wikipedia.org/wiki/Coastal_geography'}
# Hydrography
#
# Marine biology
# {'name': 'Oceanography', 'class': 'Natural', 'url': 'https://en.wikipedia.org/wiki/Oceanography'}
# {'name': 'Oceanography', 'class': 'Social', 'url': 'https://en.wikipedia.org/wiki/Oceanography'}
# Food science
# Nutrition
#
# Cuisine
# Meal

# %%
H = G.copy()
for i in sorted(nx.connected_components(H), key = len, reverse=True)[1:]:
    for j in i:
        H.remove_node(j)
        
len(sorted(nx.connected_components(H), key = len, reverse=True))
print(nx.average_shortest_path_length(H))
len(H.nodes())
# Out:
# 3.4333379948082823
# 677

# %%
import numpy
maxy = float(0.00)
max_id = 0
eigen_dic = nx.eigenvector_centrality(G)
for i in range(len(eigen_dic)):
    if eigen_dic[i] > maxy:
        maxy = eigen_dic[i]
        max_id = i
    
nodeDict = dict(G.nodes(data=True))
print(nodeDict[max_id])
print(maxy)
# Out:
# {'name': 'School psychology', 'class': 'Social', 'url': 'https://en.wikipedia.org/wiki/School_psychology'}
# 0.17068850674010985

# %%
eigen_dic = nx.degree_centrality(G)
maxy = float(0.00)
max_id = 0
for i in range(len(eigen_dic)):
    if eigen_dic[i] > maxy:
        maxy = eigen_dic[i]
        max_id = i
    
nodeDict = dict(G.nodes(data=True))
print(nodeDict[max_id])
print(max_id)
# Out:
# {'name': 'School psychology', 'class': 'Social', 'url': 'https://en.wikipedia.org/wiki/School_psychology'}
# 659

# %%
#print(nx.closeness_centrality(G))
#print(nx.betweenness_centrality(G))
#print(nx.betweenness_centrality_source(G))
#print(nx.edge_betweenness_centrality(G))
#print(nx.voterank(G))


eigen_dic = nx.betweenness_centrality(G)
{k: v for k, v in sorted(eigen_dic.items(), key=lambda item: item[1])}
print(nodeDict[98])
# Out:
# {'name': 'Algorithm', 'class': 'Formal', 'url': 'https://en.wikipedia.org/wiki/Algorithm'}

# %%
maxy = float(0.00)
max_id = 0
for i in range(len(eigen_dic)):
    if eigen_dic[i] > maxy:
        maxy = eigen_dic[i]
        max_id = i
    
nodeDict = dict(G.nodes(data=True))

print(maxy)
# Out:
# 0.07472726873078032

# %%
spl_Psy =  nx.shortest_path_length(G,659)
from statistics import mean
mean(spl_Psy[k] for k in spl_Psy)
# Out:
# 2.428360413589365
